# %% [markdown]
# # **Primeros Pasos**

# %% [markdown]
# Librerias y dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
#Leyendo el dataset

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Optimizacion/co_properties.csv')
#df = pd.read_csv('/content/co_properties.csv')

# %% [markdown]
# ## Montando el dataframe

# %%
df.shape
# Out:
# (1000000, 25)

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
#        'title', 'description', 'property_type', 'operation_type'],
#       dtype='object')

# %%
# Columnas escogidas

# new_df = df[['lat', 'lon', 'l1', 'l2', 'l3', 'bedrooms', 'bathrooms', 'price',
#              'currency', 'property_type', 'operation_type']]
new_df = df[['lat', 'lon', 'l1', 'l2', 'l3', 'rooms', 'bedrooms', 'bathrooms',
             'surface_total', 'surface_covered', 'price', 'currency', 'property_type', 'operation_type']]

# %%
new_df
# Out:
#               lat        lon        l1               l2            l3  rooms  \
# 0        3.921000 -76.506000  Colombia  Valle del Cauca           NaN    NaN
# 1        3.357700 -76.541811  Colombia  Valle del Cauca          Cali    NaN
# 2        3.357700 -76.541811  Colombia  Valle del Cauca          Cali    NaN
# 3        3.364000 -76.538000  Colombia  Valle del Cauca          Cali    NaN
# 4        3.391000 -76.517000  Colombia  Valle del Cauca          Cali    NaN
# ...           ...        ...       ...              ...           ...    ...
# 999995   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999996   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999997   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999998  11.015336 -74.831347  Colombia        Atlántico  Barranquilla    NaN
# 999999  11.017029 -74.834101  Colombia        Atlántico  Barranquilla    3.0
#
#         bedrooms  bathrooms  surface_total  surface_covered         price  \
# 0            6.0        7.0            NaN              NaN  1.300000e+09
# 1            NaN        7.0            NaN              NaN  2.800000e+09
# 2            NaN        7.0            NaN              NaN  2.800000e+09
# 3            5.0        8.0            NaN              NaN  3.500000e+09
# 4            8.0        9.0            NaN              NaN  4.800000e+08
# ...          ...        ...            ...              ...           ...
# 999995       2.0        1.0            NaN              NaN  7.000000e+05
# 999996       2.0        1.0            NaN              NaN  7.000000e+05
# 999997       2.0        1.0            NaN              NaN  7.000000e+05
# 999998       3.0        4.0            NaN              NaN  7.000000e+08
# 999999       3.0        NaN            NaN              NaN  6.450000e+08
#
#        currency property_type operation_type
# 0           COP          Casa          Venta
# 1           COP          Casa          Venta
# 2           COP          Casa          Venta
# 3           COP          Casa          Venta
# 4           COP          Casa          Venta
# ...         ...           ...            ...
# 999995      COP   Apartamento       Arriendo
# 999996      COP   Apartamento       Arriendo
# 999997      COP   Apartamento       Arriendo
# 999998      COP          Casa          Venta
# 999999      COP   Apartamento          Venta
#
# [1000000 rows x 14 columns]

# %% [markdown]
# # Limpiando el DataFrame

# %%
cleandf = new_df.copy()

# %%
cleandf
# Out:
#               lat        lon        l1               l2            l3  rooms  \
# 0        3.921000 -76.506000  Colombia  Valle del Cauca           NaN    NaN
# 1        3.357700 -76.541811  Colombia  Valle del Cauca          Cali    NaN
# 2        3.357700 -76.541811  Colombia  Valle del Cauca          Cali    NaN
# 3        3.364000 -76.538000  Colombia  Valle del Cauca          Cali    NaN
# 4        3.391000 -76.517000  Colombia  Valle del Cauca          Cali    NaN
# ...           ...        ...       ...              ...           ...    ...
# 999995   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999996   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999997   6.186412 -75.658630  Colombia        Antioquia      Medellín    NaN
# 999998  11.015336 -74.831347  Colombia        Atlántico  Barranquilla    NaN
# 999999  11.017029 -74.834101  Colombia        Atlántico  Barranquilla    3.0
#
#         bedrooms  bathrooms  surface_total  surface_covered         price  \
# 0            6.0        7.0            NaN              NaN  1.300000e+09
# 1            NaN        7.0            NaN              NaN  2.800000e+09
# 2            NaN        7.0            NaN              NaN  2.800000e+09
# 3            5.0        8.0            NaN              NaN  3.500000e+09
# 4            8.0        9.0            NaN              NaN  4.800000e+08
# ...          ...        ...            ...              ...           ...
# 999995       2.0        1.0            NaN              NaN  7.000000e+05
# 999996       2.0        1.0            NaN              NaN  7.000000e+05
# 999997       2.0        1.0            NaN              NaN  7.000000e+05
# 999998       3.0        4.0            NaN              NaN  7.000000e+08
# 999999       3.0        NaN            NaN              NaN  6.450000e+08
#
#        currency property_type operation_type
# 0           COP          Casa          Venta
# 1           COP          Casa          Venta
# 2           COP          Casa          Venta
# 3           COP          Casa          Venta
# 4           COP          Casa          Venta
# ...         ...           ...            ...
# 999995      COP   Apartamento       Arriendo
# 999996      COP   Apartamento       Arriendo
# 999997      COP   Apartamento       Arriendo
# 999998      COP          Casa          Venta
# 999999      COP   Apartamento          Venta
#
# [1000000 rows x 14 columns]

# %% [markdown]
# ## Analizando columnas

# %% [markdown]
# ### Lon y lat

# %% [markdown]
# lon

# %%
#Cantidad de no nulos y cantidad de NaN

null_lon_count = new_df['lon'].isnull().sum()
print(f"Number of non-null values in lon: {null_lon_count}")

NaN_lon_count = new_df['lon'].isna().sum()
print(f"Number of NaN values in lon: {NaN_lon_count}")
# Out:
# Number of non-null values in lon: 259718
# Number of NaN values in lon: 259718

# %% [markdown]
# lat

# %%
#Cantidad de no nulos y cantidad de NaN

null_lat_count = new_df['lat'].isnull().sum()
print(f"Number of non-null values in lat: {null_lat_count}")

NaN_lat_count = new_df['lat'].isna().sum()
print(f"Number of NaN values in lat: {NaN_lat_count}")
# Out:
# Number of non-null values in lat: 259719
# Number of NaN values in lat: 259719

# %% [markdown]
# ### l1

# %%
#Cantidad de no nulos y cantidad de NaN

null_l1_count = new_df['l1'].isnull().sum()
print(f"Number of non-null values in l1: {null_l1_count}")

NaN_l1_count = new_df['l1'].isna().sum()
print(f"Number of NaN values in l1: {NaN_l1_count}")
# Out:
# Number of non-null values in l1: 0
# Number of NaN values in l1: 0

# %%
#Mostrando discordancias

filtered_df = new_df[(new_df['l1'].notnull()) & (new_df['l1'] != 'Colombia')]

filtered_df
# Out:
#              lat        lon              l1       l2   l3  rooms  bedrooms  \
# 329928  6.152340 -75.606021  Estados Unidos  Florida  NaN    3.0       3.0
# 583696  6.152263 -75.600969  Estados Unidos  Florida  NaN    3.0       3.0
#
#         bathrooms  surface_total  surface_covered        price currency  \
# 329928        2.0            NaN              NaN  365000000.0      COP
# 583696        NaN            NaN              NaN    2200000.0      COP
#
#        property_type operation_type
# 329928   Apartamento          Venta
# 583696   Apartamento       Arriendo

# %% [markdown]
# ### l2
#  (no hay nada raro)

# %%
#Cantidad de no nulos y cantidad de NaN

null_l2_count = new_df['l2'].isnull().sum()
print(f"Number of non-null values in l1: {null_l2_count}")

NaN_l2_count = new_df['l2'].isna().sum()
print(f"Number of NaN values in l1: {NaN_l2_count}")
# Out:
# Number of non-null values in l1: 0
# Number of NaN values in l1: 0

# %% [markdown]
# ### l3
# (no afecta que existan nulos, es una variable categorica)

# %%
#Cantidad de no nulos y cantidad de NaN

null_l3_count = new_df['l3'].isnull().sum()
print(f"Number of non-null values in l3: {null_l3_count}")

NaN_l3_count = new_df['l3'].isna().sum()
print(f"Number of NaN values in l3: {NaN_l3_count}")
# Out:
# Number of non-null values in l3: 62812
# Number of NaN values in l3: 62812

# %%
#Observado errores

filtered_df = new_df[(new_df['l3'].isnull())]

filtered_df
# Out:
#               lat        lon        l1               l2   l3  rooms  bedrooms  \
# 0        3.921000 -76.506000  Colombia  Valle del Cauca  NaN    NaN       6.0
# 55       4.826252 -75.683261  Colombia        Risaralda  NaN    4.0       4.0
# 56       4.816264 -75.696573  Colombia        Risaralda  NaN    4.0       4.0
# 57       4.541471 -75.664193  Colombia          Quindío  NaN    4.0       4.0
# 58       4.826252 -75.683261  Colombia        Risaralda  NaN    4.0       4.0
# ...           ...        ...       ...              ...  ...    ...       ...
# 998160        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998161  11.380061 -72.242803  Colombia       La Guajira  NaN    NaN       NaN
# 998162        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998163        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998164        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
#
#         bathrooms  surface_total  surface_covered         price currency  \
# 0             7.0            NaN              NaN  1.300000e+09      COP
# 55            NaN            NaN              NaN  2.700000e+08      COP
# 56            NaN            NaN              NaN  1.800000e+08      COP
# 57            NaN            NaN              NaN  2.000000e+06      COP
# 58            NaN            NaN              NaN  2.700000e+08      COP
# ...           ...            ...              ...           ...      ...
# 998160        2.0            NaN              NaN  2.900000e+08      COP
# 998161        2.0            NaN              NaN  2.400000e+08      COP
# 998162        2.0            NaN              NaN  7.000000e+08      COP
# 998163        2.0            NaN              NaN  2.000000e+06      COP
# 998164        2.0            NaN              NaN  3.600000e+08      COP
#
#        property_type operation_type
# 0               Casa          Venta
# 55              Casa          Venta
# 56              Casa          Venta
# 57              Casa       Arriendo
# 58              Casa          Venta
# ...              ...            ...
# 998160   Apartamento          Venta
# 998161   Apartamento          Venta
# 998162   Apartamento          Venta
# 998163   Apartamento       Arriendo
# 998164   Apartamento          Venta
#
# [62812 rows x 14 columns]

# %% [markdown]
# ### bedrooms
# (elimina la mitad)

# %%
#Cantidad de no nulos y cantidad de NaN

null_bedrooms_count = new_df['bedrooms'].isnull().sum()
print(f"Number of non-null values in bedrooms: {null_bedrooms_count}")

NaN_bedrooms_count = new_df['bedrooms'].isna().sum()
print(f"Number of NaN values in bedrooms: {NaN_bedrooms_count}")
# Out:
# Number of non-null values in bedrooms: 623954
# Number of NaN values in bedrooms: 623954

# %% [markdown]
# ### bathrooms

# %%
#Cantidad de no nulos y cantidad de NaN

null_bathrooms_count = new_df['bathrooms'].isnull().sum()
print(f"Number of non-null values in bathrooms: {null_bathrooms_count}")

NaN_bathrooms_count = new_df['bathrooms'].isna().sum()
print(f"Number of NaN values in bathrooms: {NaN_bathrooms_count}")
# Out:
# Number of non-null values in bathrooms: 200507
# Number of NaN values in bathrooms: 200507

# %% [markdown]
# ### surface_total
#  (elimina mas del 90% xd)

# %%
#Cantidad de no nulos y cantidad de NaN en surface_total

#null_surface_total_count = new_df['surface_total'].isnull().sum()
#print(f"Number of non-null values in surface_total: {null_surface_total_count}")

#NaN_surface_total_count = new_df['surface_total'].isna().sum()
#print(f"Number of NaN values in surface_total: {NaN_surface_total_count}")

# %%
#Observado los pocos casos

#filtered_df = new_df[(new_df['surface_total'].notnull())]

filtered_df
# Out:
#               lat        lon        l1               l2   l3  rooms  bedrooms  \
# 0        3.921000 -76.506000  Colombia  Valle del Cauca  NaN    NaN       6.0
# 55       4.826252 -75.683261  Colombia        Risaralda  NaN    4.0       4.0
# 56       4.816264 -75.696573  Colombia        Risaralda  NaN    4.0       4.0
# 57       4.541471 -75.664193  Colombia          Quindío  NaN    4.0       4.0
# 58       4.826252 -75.683261  Colombia        Risaralda  NaN    4.0       4.0
# ...           ...        ...       ...              ...  ...    ...       ...
# 998160        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998161  11.380061 -72.242803  Colombia       La Guajira  NaN    NaN       NaN
# 998162        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998163        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
# 998164        NaN        NaN  Colombia        Antioquia  NaN    NaN       NaN
#
#         bathrooms  surface_total  surface_covered         price currency  \
# 0             7.0            NaN              NaN  1.300000e+09      COP
# 55            NaN            NaN              NaN  2.700000e+08      COP
# 56            NaN            NaN              NaN  1.800000e+08      COP
# 57            NaN            NaN              NaN  2.000000e+06      COP
# 58            NaN            NaN              NaN  2.700000e+08      COP
# ...           ...            ...              ...           ...      ...
# 998160        2.0            NaN              NaN  2.900000e+08      COP
# 998161        2.0            NaN              NaN  2.400000e+08      COP
# 998162        2.0            NaN              NaN  7.000000e+08      COP
# 998163        2.0            NaN              NaN  2.000000e+06      COP
# 998164        2.0            NaN              NaN  3.600000e+08      COP
#
#        property_type operation_type
# 0               Casa          Venta
# 55              Casa          Venta
# 56              Casa          Venta
# 57              Casa       Arriendo
# 58              Casa          Venta
# ...              ...            ...
# 998160   Apartamento          Venta
# 998161   Apartamento          Venta
# 998162   Apartamento          Venta
# 998163   Apartamento       Arriendo
# 998164   Apartamento          Venta
#
# [62812 rows x 14 columns]

# %% [markdown]
# ### surface_covered
# (elimina mas del 90% xd)

# %%
## Cantidad de no nulos y cantidad de NaN en surface_covered

# null_surface_covered_count = new_df['surface_covered'].isnull().sum()
# print(f"Number of non-null values in surface_covered: {null_surface_covered_count}")

# NaN_surface_covered_count = new_df['surface_covered'].isna().sum()
# print(f"Number of NaN values in surface_covered: {NaN_surface_covered_count}")

# %%
# #Observado los pocos casos

# filtered_df = new_df[(new_df['surface_covered'].notnull())]

# filtered_df

# %% [markdown]
# ### price

# %%
#Cantidad de no nulos y cantidad de NaN

null_price_count = new_df['price'].isnull().sum()
print(f"Number of non-null values in price: {null_price_count}")

NaN_price_count = new_df['price'].isna().sum()
print(f"Number of NaN values in price: {NaN_price_count}")
# Out:
# Number of non-null values in price: 509
# Number of NaN values in price: 509

# %% [markdown]
# ### currency

# %%
#Cantidad de no nulos y cantidad de NaN

null_currency_count = new_df['currency'].isnull().sum()
print(f"Number of non-null values in currency: {null_currency_count}")

NaN_currency_count = new_df['currency'].isna().sum()
print(f"Number of NaN values in currency: {NaN_currency_count}")
# Out:
# Number of non-null values in currency: 550
# Number of NaN values in currency: 550

# %%
#Mostrando discordancias

#filtered_df = new_df[(new_df['currency'].notnull()) & (new_df['currency'] != 'COP')]
filtered_df = new_df[ (new_df['currency'] != 'COP')]

filtered_df.shape
# Out:
# (598, 14)

# %% [markdown]
# ### 'property_type'

# %%
#Cantidad de no nulos y cantidad de NaN

null_property_type_count = new_df['property_type'].isnull().sum()
print(f"Number of non-null values in property_type: {null_property_type_count}")

NaN_property_type_count = new_df['property_type'].isna().sum()
print(f"Number of NaN values in property_type: {NaN_property_type_count}")
# Out:
# Number of non-null values in property_type: 0
# Number of NaN values in property_type: 0

# %%
# prompt: dentro de new_df, muestrame los distintos valores que hay en la variable 'property_type' y luego muestrame cuantos son distintos de 'Casa' y 'Apartamento'

# Valores distintos en la variable 'property_type'
distinct_property_types = new_df['property_type'].unique()
print(f"Distinct property types: {distinct_property_types}")

# Cantidad de valores distintos de 'Casa' y 'Apartamento'
non_casa_apartamento_count = new_df[~new_df['property_type'].isin(['Casa', 'Apartamento'])].shape[0]
print(f"Number of values not 'Casa' or 'Apartamento': {non_casa_apartamento_count}")
# Out:
# Distinct property types: ['Casa' 'Lote' 'Otro' 'Finca' 'Oficina' 'Apartamento' 'Local comercial'
#  'Depósito' 'Parqueadero']
# Number of values not 'Casa' or 'Apartamento': 214495

# %% [markdown]
# ### operation_type

# %%
#Cantidad de no nulos y cantidad de NaN

null_operation_type_count = new_df['operation_type'].isnull().sum()
print(f"Number of non-null values in operation_type: {null_operation_type_count}")

NaN_operation_type_count = new_df['operation_type'].isna().sum()
print(f"Number of NaN values in operation_type: {NaN_operation_type_count}")
# Out:
# Number of non-null values in operation_type: 0
# Number of NaN values in operation_type: 0

# %%
# Valores distintos en la variable 'operation_type'
distinct_operation_types = new_df['operation_type'].unique()
print(f"Distinct property types: {distinct_operation_types}")


# Cantidad de valores distintos de 'Venta'
non_venta_count = new_df[~new_df['operation_type'].isin(['Venta'])].shape[0]
print(f"Number of values not 'Venta': {non_venta_count}")
# Out:
# Distinct property types: ['Venta' 'Arriendo' 'Arriendo temporal']
# Number of values not 'Venta': 428116

# %% [markdown]
# ## Eliminando

# %%
# Eliminar de 'cleandf' donde 'lat' o 'lon' sean nulos
cleandf = cleandf[cleandf['lat'].notna() & cleandf['lon'].notna()]

# Eliminar en 'l1' donde sea distinto de Colombia
cleandf = cleandf[cleandf['l1'] == 'Colombia']

# Eliminando de 'cleandf' donde 'rooms' sea nulo
cleandf = cleandf[cleandf['rooms'].notnull()]

# Eliminando de 'cleandf' donde 'bedrooms' sea nulo
cleandf = cleandf[cleandf['bedrooms'].notnull()]

# Eliminando de 'cleandf' donde 'bathrooms' sea nulo
cleandf = cleandf[cleandf['bathrooms'].notnull()]

# Eliminando de 'cleandf' donde 'surface_total' sea nulo
cleandf = cleandf[cleandf['surface_total'].notnull()]

# Eliminando de 'cleandf' donde 'surface_covered' sea nulo
cleandf = cleandf[cleandf['surface_covered'].notnull()]

# Eliminando de 'cleandf' donde 'price' sea nulo
cleandf = cleandf[cleandf['price'].notnull()]

# Eliminar en 'curency' donde sea null o distinto de  'COP'
cleandf = cleandf[cleandf['currency'] == 'COP']

#Eliminar en 'property type' donde sean distintos de Casa y Apartamento
cleandf = cleandf[cleandf['property_type'].isin(['Casa', 'Apartamento'])]

#Mantener solo las operaciones donde sean ventas 'operatyopn_type' = 'Venta'
cleandf = cleandf[cleandf['operation_type'].isin(['Venta'])]


cleandf.shape
# Out:
# (15244, 14)

# %%
cleandf
# Out:
#           lat     lon        l1               l2          l3  rooms  bedrooms  \
# 183     3.440 -76.506  Colombia  Valle del Cauca        Cali    3.0       3.0
# 412     3.432 -76.465  Colombia  Valle del Cauca        Cali    4.0       4.0
# 413     3.432 -76.465  Colombia  Valle del Cauca        Cali    4.0       4.0
# 854     6.293 -75.598  Colombia        Antioquia    Medellín    3.0       3.0
# 873     4.753 -74.112  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# ...       ...     ...       ...              ...         ...    ...       ...
# 999865  4.729 -74.064  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999869  4.712 -74.083  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999870  4.717 -74.080  Colombia     Cundinamarca  Bogotá D.C    4.0       4.0
# 999871  4.713 -74.082  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999876  4.691 -74.061  Colombia     Cundinamarca  Bogotá D.C    1.0       1.0
#
#         bathrooms  surface_total  surface_covered         price currency  \
# 183           1.0           85.0             85.0  1.500000e+08      COP
# 412           2.0           48.0             96.0  1.250000e+08      COP
# 413           2.0           48.0             96.0  1.150000e+08      COP
# 854           2.0           74.0             74.0  1.550000e+08      COP
# 873           2.0           63.0             63.0  1.750000e+08      COP
# ...           ...            ...              ...           ...      ...
# 999865        2.0           96.0             96.0  4.400000e+08      COP
# 999869        3.0          186.0            186.0  9.800000e+08      COP
# 999870        3.0          175.0            175.0  1.300000e+09      COP
# 999871        3.0          190.0            190.0  9.500000e+08      COP
# 999876        2.0           54.0             54.0  3.600000e+08      COP
#
#        property_type operation_type
# 183             Casa          Venta
# 412             Casa          Venta
# 413             Casa          Venta
# 854             Casa          Venta
# 873             Casa          Venta
# ...              ...            ...
# 999865   Apartamento          Venta
# 999869   Apartamento          Venta
# 999870   Apartamento          Venta
# 999871   Apartamento          Venta
# 999876   Apartamento          Venta
#
# [15244 rows x 14 columns]

# %% [markdown]
# ## Normalizando

# %%
# Create two new columns for 'Casa' and 'Apartamento'
cleandf['Casa'] = cleandf['property_type'].apply(lambda x: 1 if x == 'Casa' else 0)
cleandf['Apartamento'] = cleandf['property_type'].apply(lambda x: 1 if x == 'Apartamento' else 0)

# Drop the original 'property_type' column
cleandf = cleandf.drop('property_type', axis=1)

# Display the updated DataFrame
cleandf
# Out:
#           lat     lon        l1               l2          l3  rooms  bedrooms  \
# 183     3.440 -76.506  Colombia  Valle del Cauca        Cali    3.0       3.0
# 412     3.432 -76.465  Colombia  Valle del Cauca        Cali    4.0       4.0
# 413     3.432 -76.465  Colombia  Valle del Cauca        Cali    4.0       4.0
# 854     6.293 -75.598  Colombia        Antioquia    Medellín    3.0       3.0
# 873     4.753 -74.112  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# ...       ...     ...       ...              ...         ...    ...       ...
# 999865  4.729 -74.064  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999869  4.712 -74.083  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999870  4.717 -74.080  Colombia     Cundinamarca  Bogotá D.C    4.0       4.0
# 999871  4.713 -74.082  Colombia     Cundinamarca  Bogotá D.C    3.0       3.0
# 999876  4.691 -74.061  Colombia     Cundinamarca  Bogotá D.C    1.0       1.0
#
#         bathrooms  surface_total  surface_covered         price currency  \
# 183           1.0           85.0             85.0  1.500000e+08      COP
# 412           2.0           48.0             96.0  1.250000e+08      COP
# 413           2.0           48.0             96.0  1.150000e+08      COP
# 854           2.0           74.0             74.0  1.550000e+08      COP
# 873           2.0           63.0             63.0  1.750000e+08      COP
# ...           ...            ...              ...           ...      ...
# 999865        2.0           96.0             96.0  4.400000e+08      COP
# 999869        3.0          186.0            186.0  9.800000e+08      COP
# 999870        3.0          175.0            175.0  1.300000e+09      COP
# 999871        3.0          190.0            190.0  9.500000e+08      COP
# 999876        2.0           54.0             54.0  3.600000e+08      COP
#
#        operation_type  Casa  Apartamento
# 183             Venta     1            0
# 412             Venta     1            0
# 413             Venta     1            0
# 854             Venta     1            0
# 873             Venta     1            0
# ...               ...   ...          ...
# 999865          Venta     0            1
# 999869          Venta     0            1
# 999870          Venta     0            1
# 999871          Venta     0            1
# 999876          Venta     0            1
#
# [15244 rows x 15 columns]

# %%
# prompt: Lets normalize the df ''cleandf' the values of 'property_type', 'Casa' convert to 0 and 'Apartamento' convert to 1

#cleandf['property_type'] = cleandf['property_type'].replace(['Casa', 'Apartamento'], [0, 1])

# %%
# prompt: divide entre 1000000 todos los valores dentro de la columna price en cleandf

cleandf['price'] = cleandf['price'] / 1000000000

# %%
finaldf = cleandf[['lat', 'lon', 'rooms', 'bedrooms', 'bathrooms', 'Casa', 'Apartamento', 'surface_total', 'surface_covered', 'price']]
finaldf
# Out:
#           lat     lon  rooms  bedrooms  bathrooms  Casa  Apartamento  \
# 183     3.440 -76.506    3.0       3.0        1.0     1            0
# 412     3.432 -76.465    4.0       4.0        2.0     1            0
# 413     3.432 -76.465    4.0       4.0        2.0     1            0
# 854     6.293 -75.598    3.0       3.0        2.0     1            0
# 873     4.753 -74.112    3.0       3.0        2.0     1            0
# ...       ...     ...    ...       ...        ...   ...          ...
# 999865  4.729 -74.064    3.0       3.0        2.0     0            1
# 999869  4.712 -74.083    3.0       3.0        3.0     0            1
# 999870  4.717 -74.080    4.0       4.0        3.0     0            1
# 999871  4.713 -74.082    3.0       3.0        3.0     0            1
# 999876  4.691 -74.061    1.0       1.0        2.0     0            1
#
#         surface_total  surface_covered  price
# 183              85.0             85.0  0.150
# 412              48.0             96.0  0.125
# 413              48.0             96.0  0.115
# 854              74.0             74.0  0.155
# 873              63.0             63.0  0.175
# ...               ...              ...    ...
# 999865           96.0             96.0  0.440
# 999869          186.0            186.0  0.980
# 999870          175.0            175.0  1.300
# 999871          190.0            190.0  0.950
# 999876           54.0             54.0  0.360
#
# [15244 rows x 10 columns]

# %% [markdown]
# # **Modelos**

# %%
corr = finaldf.corr()

corr
# Out:
#                       lat       lon     rooms  bedrooms  bathrooms      Casa  \
# lat              1.000000  0.395951 -0.121715 -0.121715  -0.119243 -0.098704
# lon              0.395951  1.000000 -0.068703 -0.068703  -0.037101  0.030198
# rooms           -0.121715 -0.068703  1.000000  1.000000   0.638613  0.482336
# bedrooms        -0.121715 -0.068703  1.000000  1.000000   0.638613  0.482336
# bathrooms       -0.119243 -0.037101  0.638613  0.638613   1.000000  0.435241
# Casa            -0.098704  0.030198  0.482336  0.482336   0.435241  1.000000
# Apartamento      0.098704 -0.030198 -0.482336 -0.482336  -0.435241 -1.000000
# surface_total   -0.049752  0.017989  0.122997  0.122997   0.203524  0.170338
# surface_covered  0.003838  0.010141 -0.004645 -0.004645   0.004820 -0.008976
# price           -0.075037  0.076471  0.270220  0.270220   0.542390  0.258244
#
#                  Apartamento  surface_total  surface_covered     price
# lat                 0.098704      -0.049752         0.003838 -0.075037
# lon                -0.030198       0.017989         0.010141  0.076471
# rooms              -0.482336       0.122997        -0.004645  0.270220
# bedrooms           -0.482336       0.122997        -0.004645  0.270220
# bathrooms          -0.435241       0.203524         0.004820  0.542390
# Casa               -1.000000       0.170338        -0.008976  0.258244
# Apartamento         1.000000      -0.170338         0.008976 -0.258244
# surface_total      -0.170338       1.000000        -0.000682  0.310037
# surface_covered     0.008976      -0.000682         1.000000  0.008054
# price              -0.258244       0.310037         0.008054  1.000000

# %%
plt.figure(figsize=(16, 9))
sns.heatmap(corr, vmin=-1, vmax=1, annot=True)
plt.show()

# %%
inputs = ['lat','lon', 'rooms', 'bedrooms', 'bathrooms',  'Casa','Apartamento', 'surface_total']
output= ['price']

# %%
dfTrain, dfTest = train_test_split(finaldf, test_size=.3, random_state=10)

# %% [markdown]
# ## ***Reg lineal***

# %%
lr = LinearRegression()
lr.fit(dfTrain[inputs], dfTrain[output])
# Out:
# LinearRegression()

# %%
lr.score(dfTest[inputs], dfTest[output])
# Out:
# 0.3752581201686437

# %%
lr.intercept_
# Out:
# array([5.84566443])

# %%
lr.coef_
# Out:
# array([[-2.01320506e-02,  7.75304149e-02, -3.30623090e-02,
#         -3.30623090e-02,  3.22487422e-01,  2.59257023e-02,
#         -2.59257023e-02,  5.94547755e-05]])

# %%
lr.predict(dfTest[inputs]).flatten()
# Out:
# array([1.59669768, 1.05299423, 0.64850543, ..., 0.80440969, 0.57281011,
#        0.6256587 ])

# %% [markdown]
# ## ***RandomForest***

# %%
rf = RandomForestRegressor(n_estimators=500, random_state=10)
rf.fit(dfTrain[inputs], dfTrain[output])
# Out:
# <ipython-input-47-33043bcda389>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(dfTrain[inputs], dfTrain[output])
# RandomForestRegressor(n_estimators=500, random_state=10)

# %%
rf.score(dfTest[inputs], dfTest[output])
# Out:
# 0.7996369275301007

# %%
y_pred= rf.predict(dfTest[inputs]).flatten()

# %%
y_pred
# Out:
# array([1.153788  , 0.96      , 0.37072448, ..., 0.38930048, 0.38706119,
#        0.27516796])

# %%
y_real = dfTest[output]

# %%
y_real = dfTest[output].values.flatten()

# %%
y_real
# Out:
# array([0.95 , 0.96 , 0.345, ..., 0.365, 0.36 , 0.26 ])

# %%
  plt.figure(figsize=(8, 6))
  reg_plot = sns.regplot(x=y_pred, y=y_real,
                        scatter_kws={'color': 'skyblue', 's': 30},
                        line_kws={'color': 'red', 'lw': 2})

  plt.title('Valores Actuales vs Valores Predichos  ' , fontsize=18)
  plt.xlabel('Valores Predichos', fontsize=16)
  plt.ylabel('Valores Actuales', fontsize=16)

  plt.grid(True, which='both', linestyle='--', linewidth=0.5)

  plt.xticks(fontsize=14)
  plt.yticks(fontsize=14)

  plt.tight_layout()
  plt.show()

# %%
dfTest.head(3)
# Out:
#           lat     lon  rooms  bedrooms  bathrooms  Casa  Apartamento  \
# 84389   5.267 -73.917    6.0       6.0        6.0     1            0
# 303108  4.194 -74.678    4.0       4.0        4.0     1            0
# 53435   3.368 -76.517    3.0       3.0        3.0     1            0
#
#         surface_total  surface_covered  price
# 84389           400.0            300.0  0.950
# 303108          508.0            350.0  0.960
# 53435           135.0            115.0  0.345

# %% [markdown]
# ## ***GradientBoostingRegressor***

# %%
gb = GradientBoostingRegressor(n_estimators=700, learning_rate=0.1, random_state=42)
gb.fit(dfTrain[inputs], dfTrain[output])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(n_estimators=700, random_state=42)

# %%
gb.score(dfTest[inputs], dfTest[output])
# Out:
# 0.7767888497883069

# %%
gb.predict(dfTest[inputs]).flatten()
# Out:
# array([1.32986726, 0.92075035, 0.43079936, ..., 0.35955394, 0.42598504,
#        0.30115267])

# %%
dfTest.head(3)
# Out:
#           lat     lon  rooms  bedrooms  bathrooms  Casa  Apartamento  \
# 84389   5.267 -73.917    6.0       6.0        6.0     1            0
# 303108  4.194 -74.678    4.0       4.0        4.0     1            0
# 53435   3.368 -76.517    3.0       3.0        3.0     1            0
#
#         surface_total  surface_covered  price
# 84389           400.0            300.0  0.950
# 303108          508.0            350.0  0.960
# 53435           135.0            115.0  0.345

# %% [markdown]
# # ***Redes Neuronales***

# %%
from sklearn.neural_network import MLPRegressor

# %%
inputs = ['lat','lon', 'rooms', 'bedrooms', 'bathrooms',  'Casa','Apartamento', 'surface_total']
output= ['price']

# %%
dfTrain, dfTest = train_test_split(finaldf, test_size=.3, random_state=10)

# %% [markdown]
# ## Modelo 1

# %%
mlp_ = MLPRegressor(hidden_layer_sizes=(10, 10, 10, 10, 10), activation='identity', alpha=0.5,)
mlp_.fit(dfTrain[inputs], dfTrain[output])
mlp_.score(dfTest[inputs], dfTest[output])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1623: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9983426418815329

# %% [markdown]
# # **Mapa**

# %%
# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4, -70], zoom_start=8)

# Función para determinar el color del marcador en función del precio
def color_by_price(price):
    if price < 1:
        color = 'green'
    elif price < 2:
        color = 'orange'
    else:
        color = 'red'
    return color

# Agregar marcadores al mapa
for index, row in pos.iterrows():
    folium.CircleMarker(location=[row['lat'], row['lon']],
                       radius=5,
                       color=color_by_price(row['price'])).add_to(mapa)

# Guardar el mapa en un archivo HTML
mapa.save('mapa_precios.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-5f6a76b88d66> in <cell line: 15>()
#      13
#      14 # Agregar marcadores al mapa
# ---> 15 for index, row in pos.iterrows():
#      16     folium.CircleMarker(location=[row['lat'], row['lon']],
#      17                        radius=5,
#
# NameError: name 'pos' is not defined

# %%
mapa
